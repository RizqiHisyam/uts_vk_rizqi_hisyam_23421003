# %% [markdown]
# <a href="https://colab.research.google.com/gist/iyungrozy/3a985d4507ffa92ecee6fef1cd1b2cda/thresholding_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread('kucing.jpg')

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %%
result = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(result)
# Out:
# <PIL.Image.Image image mode=L size=225x225>

# %%
ret, thresh1 = cv2.threshold(result, 50, 300, cv2.THRESH_BINARY)
ret, thresh3 = cv2.threshold(result, 50, 300, cv2.THRESH_TRUNC)
ret, thresh4 = cv2.threshold(result, 50, 300, cv2.THRESH_TOZERO)

# %%
cv2_imshow(thresh1)
cv2_imshow(thresh3)
cv2_imshow(thresh4)
# Out:
# <PIL.Image.Image image mode=L size=225x225>
# <PIL.Image.Image image mode=L size=225x225>
# <PIL.Image.Image image mode=L size=225x225>
